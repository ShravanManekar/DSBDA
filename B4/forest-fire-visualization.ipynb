# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/sanjanabodade/forest-fire-ds/forestfires.csv

# %%
# =====================================================
# VISUALIZATION OF FOREST FIRE DATASET
# USING MATPLOTLIB & SEABORN
# =====================================================

# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# =====================================================
# LOAD DATASET
# =====================================================

forest_df = pd.read_csv("/kaggle/input/datasets/sanjanabodade/forest-fire-ds/forestfires.csv")

print("First 5 Rows:")
print(forest_df.head())

# =====================================================
# 1. HISTOGRAM
# Temperature Distribution
# =====================================================

plt.figure(figsize=(8,5))

plt.hist(forest_df['temp'], bins=20)

plt.title("Temperature Distribution")
plt.xlabel("Temperature")
plt.ylabel("Frequency")

plt.show()

# =====================================================
# 2. BAR PLOT
# Monthwise Burned Area
# =====================================================

plt.figure(figsize=(10,5))

sns.barplot(x='month',
            y='area',
            data=forest_df)

plt.title("Monthwise Burned Area")
plt.xlabel("Month")
plt.ylabel("Burned Area")

plt.show()

# =====================================================
# 3. SCATTER PLOT
# Temperature vs Burned Area
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(forest_df['temp'],
            forest_df['area'])

plt.title("Temperature vs Burned Area")
plt.xlabel("Temperature")
plt.ylabel("Burned Area")

plt.show()

# =====================================================
# 4. LINE PLOT
# Temperature Variation
# =====================================================

plt.figure(figsize=(10,5))

plt.plot(forest_df['temp'])

plt.title("Temperature Variation")
plt.xlabel("Index")
plt.ylabel("Temperature")

plt.show()

# =====================================================
# 5. BOX PLOT
# Wind Speed Distribution
# =====================================================

plt.figure(figsize=(6,5))

sns.boxplot(y=forest_df['wind'])

plt.title("Wind Speed Distribution")

plt.show()

# =====================================================
# 6. HEATMAP
# Correlation Matrix
# =====================================================

plt.figure(figsize=(10,8))

sns.heatmap(
    forest_df.corr(numeric_only=True),
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()

# =====================================================
# END OF PROGRAM
# =====================================================
# Out:
# First 5 Rows:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0
